# %%
import gzip
import random

##### FASTA #####
def reading_dnaFasta(filename):
    '''
    WHAT IT DOES
    '''
    infile = open(filename, 'r')
    header = ''
    sequence = ''

    for line in infile:
        line = line.strip()
        if line.startswith('>'):
            if header != '':
                yield header, sequence
            header = line[1:]
            sequence = ''
        else:
            sequence += line
    if sequence != '':
        yield header, sequence

    infile.close()


##### Length and sequences dict #####
def read_fasta_dict(filename):
    '''
    Returns gene_length and gene_sequences with the key being the gene
    '''
    gene_length = {}
    gene_sequences = {}

    for header, seq in reading_dnaFasta(filename):
        name = header.strip().split(' ')[0]
        gene_length[name] = len(seq)
        gene_sequences[name] = seq

    return gene_length, gene_sequences


##### Reverse Complement Strand #####
def reverse_com_strand(sequence):
    '''
    Returns the reverse complement of the input sequence
    '''
    comp = {'A':'T','T':'A','G':'C','C':'G'}
    rev = []
    for base in sequence[::-1]:
        if base in comp:
            rev.append(comp[base])
        else:
            rev.append('N')

    return ''.join(rev)


##### Kmer and position of kmer in the sequence #####
def nineteen_pos(DNA):
    '''
    Takes out a DNA sequence and returns a kmer and its position in the sequence
    '''
    for i in range(len(DNA) - 18):
        kmer = DNA[i:i+19]
        if 'N' not in kmer:
            yield i, kmer


##### Dict of all kmers for all resistance genes (with their positions) #####
def create_dict_kmer(fasta_file):
    '''
    For the resistance genes. Takes all genes and their sequences.
    Computes the kmers for all gene sequences, both forward and reverse.
    Each k-mer maps to a list of (gene_name, position, strand) entries
    '''
    kmer_index = {}

    for header, sequence in reading_dnaFasta(fasta_file):
        gene_name = header.strip().split(' ')[0]

        for position, kmer in nineteen_pos(sequence):
            if kmer not in kmer_index:
                kmer_index[kmer] = []
            kmer_index[kmer].append((gene_name, position, '+'))
        
        rev = reverse_com_strand(sequence)
        for rev_position, kmer in nineteen_pos(rev):
            if kmer not in kmer_index:
                kmer_index[kmer] = []
            kmer_index[kmer].append((gene_name, rev_position, '-'))

    return kmer_index


##### FASTQ File  #####

def fastqread(filename):
    '''
    Inputs the fastq file and yields the sequence of each read in the file
    '''
    infile = gzip.open(filename, 'rt')

    while True:
        infile.readline()
        seq = infile.readline().rstrip()
        infile.readline()
        infile.readline()

        if len(seq) == 0:
            break

        yield seq

    infile.close()


# ----------------------------
# MAIN ALGORITHM
# ----------------------------


##### Matching the reads to the reference genes #######
def match_reads_to_genes(fastq_files, resistance_kmer, gene_lengths):
    '''
    Map sequencing reads to reference genes using k-mer matches (19 length kmers)
    The coverage is only counted at position supported byt at least one matching kmer
    
    For each read, we:
     - Find all possible alignments based on shared k-mers
     - Keep only the best alignments (the ones with most matches)
     - Increase coverage across the positions of the aligned region of the gene that are backed by k-mer matches

    This approach avoids false gaps caused by SNPs or sequencing errors,
    while still distinguishing between similar genes.
    '''

    # check if we can use it like this
    dict_depth = {gene: [0] * length for gene, length in gene_lengths.items()}
    unique_match_counts = {gene: 0 for gene in gene_lengths}

    for fastq in fastq_files:
        for read in fastqread(fastq):
            read_len = len(read)

            if read_len < 19:
                continue

            # First filter to remove 
            possible_hit = False
            for pos in range(0, read_len - 18, 20):
                kmer = read[pos:pos + 19]
                if 'N' in kmer:
                    continue
                if kmer in resistance_kmer:
                    possible_hit = True
                    break
            if not possible_hit:
                continue

            # Group k-mer hits per read into alignment hypotheses
            # (gene, alignment_shift, strand) -> [total_hits, unique_hits, matched_read_positions]
            reads_found_gene = {}

            for read_pos in range(read_len - 18):
                kmer_read = read[read_pos:read_pos + 19]
                if 'N' in kmer_read or kmer_read not in resistance_kmer:
                    continue

                genes_matched = resistance_kmer[kmer_read]  # matches = list of (gene, alignment_shift, strand) for all hits

                # kmer is unique if every entry maps to the same gene
                first_gene_matched = genes_matched[0][0]
                unique = True 
                for entry in genes_matched:
                    if entry[0] != first_gene_matched: # If any match has a different gene name it means that it is not unique 
                        unique = False
                        break

                for gene, gene_pos, strand in genes_matched:
                    alignment_shift = gene_pos - read_pos
                    id = (gene, alignment_shift, strand)
                    if id not in reads_found_gene:
                        # [total_hits, unique_hits]
                        reads_found_gene[id] = [0, 0]    # total hits
                    reads_found_gene[id][0] += 1

                    if unique:
                        reads_found_gene[id][1] += 1
                
            if not reads_found_gene:
                continue 

            # Best-hits attribution: only credit alignments tied at max hits
            best_hits = 0
            for info in reads_found_gene.values():
                if info[0] > best_hits:
                    best_hits = info[0]

            if best_hits < 3:  # ignore noise/ random matches
                continue

            for (gene, shift, strand), (hit_count, unique_hits) in reads_found_gene.items():
                if hit_count == best_hits:
                    gene_len = gene_lengths[gene]
                    # Convert each read position into a gene position
                    if strand == '+':
                        start = shift
                        end = shift + read_len - 1
                    else:
                        start = gene_len - shift - read_len  # map it in the forward coordinates
                        end = gene_len - 1 - shift
                    
                    if start < 0:
                        start = 0
                    if end > gene_len - 1:
                        end = gene_len - 1

                    for p in range(start, end + 1):
                        dict_depth[gene][p] += 1
                    unique_match_counts[gene] += unique_hits
    
    return dict_depth, unique_match_counts



##### Compute coverage and depth; Posterior filtering #######

def calculate_coverage_depth(dict_depth, gene_length, min_cov=95, min_depth=10, pos_min_depth=1):
    '''
    Filter genes by minimum core coverage and average core depth
    '''
    filtered_genes = {}

    for gene, pos_counts in dict_depth.items():   
        gene_len = gene_length[gene]

        core_start = 18
        core_end = gene_len - 18

        if core_end <= core_start:
            continue

        core = pos_counts[core_start:core_end]
        n = len(core)

        covered = sum(1 for d in core if d > 0)
        coverage = covered / n * 100
        avg_depth = sum(core) / n

        if coverage >= min_cov and avg_depth >= min_depth:
            filtered_genes[gene] = {
                'coverage': coverage,
                'depth': avg_depth,
                'min_depth': min(core)
            }

    return filtered_genes


def join_genes_by_similarity(resistance_kmer, gene_length, filtered_genes,
                             dict_unique_hits, threshold=0.5):
    """Collapse near-identical alleles among the genes that passed the filter.

    If two genes share >= threshold of the SMALLER gene's reference k-mer
    set, they are treated as alleles of the same family and only one is
    kept. Tie-break order: coverage > avg depth > unique-hit count.
    """
    # Build a gene -> set of reference k-mers from the kmer index
    gene_kmers = {gene: set() for gene in gene_length}
    for kmer, entries in resistance_kmer.items():
        for gene, position, strand in entries:
            gene_kmers[gene].add(kmer)

    # Only compare genes that actually passed the filter 
    gene_list = list(filtered_genes.keys())
    removed = set()

    for i in range(len(gene_list)):
        for j in range(i + 1, len(gene_list)):
            gene_a, gene_b = gene_list[i], gene_list[j]

            if gene_a in removed or gene_b in removed:
                continue

            kmer_a, kmer_b = gene_kmers[gene_a], gene_kmers[gene_b]
            shared = len(kmer_a & kmer_b)   ### problem to have this here

            if shared == 0:
                continue
            
            # Problem here also
            smaller = kmer_a if len(kmer_a) <= len(kmer_b) else kmer_b
            similarity = shared / len(smaller)
            
            if similarity >= threshold:
                stat_a, stat_b = filtered_genes[gene_a], filtered_genes[gene_b]
                if stat_a['coverage'] != stat_b['coverage']:
                    better, worse = (gene_a, gene_b) if stat_a['coverage'] > stat_b['coverage'] else (gene_b, gene_a)
                elif stat_a['depth'] != stat_b['depth']:
                    better, worse = (gene_a, gene_b) if stat_a['depth'] > stat_b['depth'] else (gene_b, gene_a)
                else:
                    better, worse = (gene_a, gene_b) if dict_unique_hits[gene_a] >= dict_unique_hits[gene_b] else (gene_b, gene_a)
                removed.add(worse)

    final = {}
    for gene in filtered_genes:
        if gene not in removed:
            final[gene] = {
                'gene': gene,
                'coverage': filtered_genes[gene]['coverage'],
                'depth': filtered_genes[gene]['depth'],
                'min_depth': filtered_genes[gene]['min_depth'],
            }

    return final, removed


# ----------------------------
# MAIN RUNNING
# ----------------------------

if __name__ == '__main__':

    fasta_file = 'resistance_genes.fsa.txt'
    fastq_files = ['Unknown3_raw_reads_1.txt.gz', 'Unknown3_raw_reads_2.txt.gz']

    gene_length, gene_sequences = read_fasta_dict(fasta_file)
    resistance_kmer = create_dict_kmer(fasta_file)

    dict_depth, dict_unique_hits = match_reads_to_genes(
        fastq_files, resistance_kmer, gene_length)

    filtered_genes = calculate_coverage_depth(
        dict_depth,
        gene_length)

    final_genes, removed = join_genes_by_similarity(resistance_kmer, gene_length, filtered_genes,
                                dict_unique_hits, threshold=0.5)

    sorted_genes = sorted(final_genes.items(), key=lambda x: (-x[1]['coverage'], -x[1]['depth'], -x[1]['min_depth']))

    for gene, stats in sorted_genes:
        print(gene, "| coverage:", round(stats['coverage'], 2), "| depth:", round(stats['depth'], 2), "| min_depth:", round(stats['min_depth'], 2))
# Out:
# catB4_1_EU935739 | coverage: 100.0 | depth: 144.62 | min_depth: 38
# fosA_3_ACWO01000079 | coverage: 100.0 | depth: 140.1 | min_depth: 62
# oqxA_1_EU370913 | coverage: 100.0 | depth: 132.53 | min_depth: 94
# oqxB_1_EU370913 | coverage: 100.0 | depth: 124.51 | min_depth: 80
# blaSHV-28_1_HM751101 | coverage: 100.0 | depth: 91.93 | min_depth: 77
# tet(A)_4_AJ517790 | coverage: 100.0 | depth: 70.49 | min_depth: 44
# aac(3)-IIa_1_CP023555.1 | coverage: 100.0 | depth: 56.91 | min_depth: 43
# aac(6')Ib-cr_1_DQ303918 | coverage: 100.0 | depth: 55.87 | min_depth: 38
# strB_1_M96392 | coverage: 100.0 | depth: 53.89 | min_depth: 42
# dfrA14_1_DQ388123 | coverage: 100.0 | depth: 52.41 | min_depth: 31
# blaCTX-M-15_23_DQ302097 | coverage: 100.0 | depth: 51.15 | min_depth: 28
# blaTEM-1B_1_JF910132 | coverage: 100.0 | depth: 50.46 | min_depth: 38
# strA_4_AF321551 | coverage: 100.0 | depth: 50.25 | min_depth: 33
# blaOXA-1_1_J02967 | coverage: 100.0 | depth: 49.52 | min_depth: 36
# sul2_2_GQ421466 | coverage: 100.0 | depth: 45.31 | min_depth: 30

# %%
# ----------------------------
# PRINTING SOME EXTRAS TO UNDERSTAND ALGORITHM
# ----------------------------

##### Find the most similar gene in the whole database #####
def find_closest_homolog(target_gene, resistance_kmer):
    '''
    Looks through the k-mer index to find which gene in the database
    is the most similar to our target_gene (besides itself).
    '''
    target_kmers = set()
    all_other_kmers = {}
    
    # Organize kmers into sets for comparison
    for kmer, entries in resistance_kmer.items():
        for entry in entries:
            gene_name = entry[0]
            if gene_name == target_gene:
                target_kmers.add(kmer)
            else:
                if gene_name not in all_other_kmers:
                    all_other_kmers[gene_name] = set()
                all_other_kmers[gene_name].add(kmer)

    if not target_kmers:
        return None, 0.0

    best_match_name = None
    highest_similarity = 0.0
    
    # Loop through every other gene to find the best overlap
    for other_gene, other_kmers in all_other_kmers.items():
        shared_kmers = len(target_kmers & other_kmers)
        if shared_kmers == 0:
            continue
            
        # Similarity = shared / smaller (Student method)
        if len(target_kmers) < len(other_kmers):
            smaller_size = len(target_kmers)
        else:
            smaller_size = len(other_kmers)
            
        current_similarity = shared_kmers / smaller_size
        
        if current_similarity > highest_similarity:
            highest_similarity = current_similarity
            best_match_name = other_gene
            
    return best_match_name, highest_similarity


##### Calculate core metrics (Coverage and Depth) #####
def _stats(depth_list, k_value=19): 
    '''
    Cuts the edges of the gene (k-1) and calculates 
    how much is covered and the average depth.
    '''
    # Extract the core region
    core_region = depth_list[k_value - 1 : -(k_value - 1)]
    number_of_bases = len(core_region)
    
    if number_of_bases <= 0:
        return None
        
    # Count how many bases have at least one read
    covered_count = 0
    for depth in core_region:
        if depth > 0:
            covered_count += 1
            
    sum_of_depths = sum(core_region)
    
    # Return a dictionary with all the math results
    return {
        'total_length': len(depth_list),
        'core_length': number_of_bases,
        'covered_bases': covered_count,
        'depth_sum': sum_of_depths,
        'coverage_pct': (covered_count / number_of_bases) * 100,
        'average_depth': sum_of_depths / number_of_bases,
        'minimum_depth': min(core_region) if core_region else 0,
        'zero_positions': number_of_bases - covered_count
    }


##### Step-by-step math explanation #####
def print_gene_explanation(gene_name, dict_depth, k_value=19):
    '''
    Prints the step-by-step math for the final report.
    '''
    if gene_name not in dict_depth:
        print("Could not find gene: " + gene_name)
        return
        
    stats_results = _stats(dict_depth[gene_name], k_value)
    if stats_results is None:
        return
        
    print(f"\n--- Analysis for: {gene_name}")
    print(f"Total Gene Length: {stats_results['total_length']} bp")
    print(f"Core Region (excluding edges): {stats_results['core_length']} bp")
    print(f"Positions with at least 1 read: {stats_results['covered_bases']}")
    print(f"Coverage = ({stats_results['covered_bases']} / {stats_results['core_length']}) * 100 = {stats_results['coverage_pct']:.2f}%")
    print(f"Total depth sum in core: {stats_results['depth_sum']}")
    print(f"Average Depth = {stats_results['depth_sum']} / {stats_results['core_length']} = {stats_results['average_depth']:.2f}x")
    print(f"Number of Gaps: {stats_results['zero_positions']}")


##### Visual comparison of winner vs another gene #####
def plot_winner_vs_homolog(resistance_kmer, gene_length, 
                           dict_depth, final_results,
                           similarity_threshold=0.5):
    '''
    Finds a winner and its closest relative in the whole database
    to show them side-by-side on a plot.
    '''
    import matplotlib.pyplot as plt
    import random
    k_size = 19

    all_gene_kmers = {name: set() for name in gene_length}
    for kmer, mapping_list in resistance_kmer.items():
        for entry in mapping_list:
            all_gene_kmers[entry[0]].add(kmer)

    winner_names = list(final_results.keys())
    random.shuffle(winner_names) # This now works because we stop early!

    best_winner = None
    best_homolog = None
    max_sim_found = 0.0
    
    for winner in winner_names:
        winner_kmers = all_gene_kmers[winner]
        
        # We look for the best relative for THIS specific random winner
        current_best_sim = 0.0
        current_best_homolog = None
        
        for any_gene in all_gene_kmers:
            if any_gene == winner:
                continue
                
            other_kmers = all_gene_kmers[any_gene]
            shared = len(winner_kmers & other_kmers)
            if shared == 0:
                continue
            
            smaller = min(len(winner_kmers), len(other_kmers))
            sim_score = shared / smaller
            
            if sim_score > current_best_sim:
                current_best_sim = sim_score
                current_best_homolog = any_gene
        
        # If this winner has a relative above the threshold, we take it and STOP
        if current_best_sim >= similarity_threshold:
            best_winner = winner
            best_homolog = current_best_homolog
            max_sim_found = current_best_sim
            break # <--- THIS IS THE KEY: Stop looking at other winners!

    if best_winner is None:
        print("No pairs found for plotting")
        return

    # ... (Rest of the plotting code remains the same) ...
    winner_stats = _stats(dict_depth[best_winner], k_size)
    homolog_stats = _stats(dict_depth[best_homolog], k_size)

    fig, (ax_left, ax_right) = plt.subplots(1, 2, figsize=(14, 4))
    
    # Plot for the winner
    ax_left.plot(dict_depth[best_winner], color='seagreen', linewidth=0.8)
    ax_left.fill_between(range(len(dict_depth[best_winner])), dict_depth[best_winner], color='seagreen', alpha=0.2)
    
    ax_left.axvline(x=k_size - 1, color='red', linestyle='--', linewidth=0.8)
    ax_left.axvline(x=len(dict_depth[best_winner]) - (k_size - 1), color='red', linestyle='--', linewidth=0.8)
    
    ax_left.set_title(f"Winner: {best_winner}\nCoverage: {winner_stats['coverage_pct']:.1f}%")
    
    # Plot for the homolog
    ax_right.plot(dict_depth[best_homolog], color='steelblue', linewidth=0.8)
    ax_right.fill_between(range(len(dict_depth[best_homolog])), dict_depth[best_homolog], color='steelblue', alpha=0.2)
    
    ax_right.axvline(x=k_size - 1, color='red', linestyle='--', linewidth=0.8)
    ax_right.axvline(x=len(dict_depth[best_homolog]) - (k_size - 1), color='red', linestyle='--', linewidth=0.8)
    
    ax_right.set_title(f"Homolog: {best_homolog}\nCoverage: {homolog_stats['coverage_pct']:.1f}%")

    plt.suptitle(f"Winner vs Closest Homolog (Similarity: {max_sim_found:.3f})")
    plt.tight_layout()
    plt.show()


# ----------------------------
# MAIN EXECUTION
# ----------------------------

if __name__ == '__main__':
    # Selected genes for the report
    target_genes_list = [
        "aac(6')Ib-cr_1_DQ303918",
        "strA_4_AF321551",
        "strB_1_M96392",
        "aac(3)-IIa_1_CP023555.1",
        "blaCTX-M-15_23_DQ302097",
        "blaOXA-1_1_J02967",
        "blaSHV-28_1_HM751101",
        "blaTEM-1B_1_JF910132",
        "fosA_3_ACWO01000079",
        "catB4_1_EU935739",
        "oqxA_1_EU370913",
        "oqxB_1_EU370913",
        "sul2_2_GQ421466",
        "tet(A)_4_AJ517790",
        "dfrA14_1_DQ388123"]
    
    # Show the plot
    plot_winner_vs_homolog(resistance_kmer, gene_length, dict_depth, final_genes)

    # Print the report
    print(f"{'TARGET GENE FROM LIST vs CLOSEST DATABASE HOMOLOG'}")
    print("." * 100)

    for current_gene in target_genes_list:
        # Show stats for the gene we found
        print_gene_explanation(current_gene, dict_depth)
        
        # Find who is most like it in the database
        closest_name, similarity_value = find_closest_homolog(current_gene, resistance_kmer)
        
        if closest_name:
            print(f"\n> Closest Homolog: {closest_name}")
            print(f"> Similarity Score: {similarity_value:.4f}")
            print_gene_explanation(closest_name, dict_depth)
        else:
            print("\n> No similar genes found")

        print("\n")
        print("." * 100)
# Out:
# TARGET GENE FROM LIST vs CLOSEST DATABASE HOMOLOG
# ....................................................................................................
#
# --- Analysis for: aac(6')Ib-cr_1_DQ303918
# Total Gene Length: 600 bp
# Core Region (excluding edges): 564 bp
# Positions with at least 1 read: 564
# Coverage = (564 / 564) * 100 = 100.00%
# Total depth sum in core: 31511
# Average Depth = 31511 / 564 = 55.87x
# Number of Gaps: 0
#
# > Closest Homolog: aac(6')Ib-cr_2_EF636461
# > Similarity Score: 0.9621
#
# --- Analysis for: aac(6')Ib-cr_2_EF636461
# Total Gene Length: 519 bp
# Core Region (excluding edges): 483 bp
# Positions with at least 1 read: 481
# Coverage = (481 / 483) * 100 = 99.59%
# Total depth sum in core: 18472
# Average Depth = 18472 / 483 = 38.24x
# Number of Gaps: 2
#
#
# ....................................................................................................
#
# --- Analysis for: strA_4_AF321551
# Total Gene Length: 804 bp
# Core Region (excluding edges): 768 bp
# Positions with at least 1 read: 768
# Coverage = (768 / 768) * 100 = 100.00%
# Total depth sum in core: 38592
# Average Depth = 38592 / 768 = 50.25x
# Number of Gaps: 0
#
# > Closest Homolog: strA_1_M96392
# > Similarity Score: 0.9758
#
# --- Analysis for: strA_1_M96392
# Total Gene Length: 804 bp
# Core Region (excluding edges): 768 bp
# Positions with at least 1 read: 768
# Coverage = (768 / 768) * 100 = 100.00%
# Total depth sum in core: 33643
# Average Depth = 33643 / 768 = 43.81x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: strB_1_M96392
# Total Gene Length: 837 bp
# Core Region (excluding edges): 801 bp
# Positions with at least 1 read: 801
# Coverage = (801 / 801) * 100 = 100.00%
# Total depth sum in core: 43167
# Average Depth = 43167 / 801 = 53.89x
# Number of Gaps: 0
#
# > Closest Homolog: strB_3_AF024602
# > Similarity Score: 0.9768
#
# --- Analysis for: strB_3_AF024602
# Total Gene Length: 837 bp
# Core Region (excluding edges): 801 bp
# Positions with at least 1 read: 801
# Coverage = (801 / 801) * 100 = 100.00%
# Total depth sum in core: 38659
# Average Depth = 38659 / 801 = 48.26x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: aac(3)-IIa_1_CP023555.1
# Total Gene Length: 861 bp
# Core Region (excluding edges): 825 bp
# Positions with at least 1 read: 825
# Coverage = (825 / 825) * 100 = 100.00%
# Total depth sum in core: 46951
# Average Depth = 46951 / 825 = 56.91x
# Number of Gaps: 0
#
# > Closest Homolog: aac(3)-IIa_1_X51534
# > Similarity Score: 0.9751
#
# --- Analysis for: aac(3)-IIa_1_X51534
# Total Gene Length: 861 bp
# Core Region (excluding edges): 825 bp
# Positions with at least 1 read: 822
# Coverage = (822 / 825) * 100 = 99.64%
# Total depth sum in core: 42786
# Average Depth = 42786 / 825 = 51.86x
# Number of Gaps: 3
#
#
# ....................................................................................................
#
# --- Analysis for: blaCTX-M-15_23_DQ302097
# Total Gene Length: 876 bp
# Core Region (excluding edges): 840 bp
# Positions with at least 1 read: 840
# Coverage = (840 / 840) * 100 = 100.00%
# Total depth sum in core: 42969
# Average Depth = 42969 / 840 = 51.15x
# Number of Gaps: 0
#
# > Closest Homolog: blaCTX-M-3_2_EF437434
# > Similarity Score: 0.9779
#
# --- Analysis for: blaCTX-M-3_2_EF437434
# Total Gene Length: 876 bp
# Core Region (excluding edges): 840 bp
# Positions with at least 1 read: 838
# Coverage = (838 / 840) * 100 = 99.76%
# Total depth sum in core: 39131
# Average Depth = 39131 / 840 = 46.58x
# Number of Gaps: 2
#
#
# ....................................................................................................
#
# --- Analysis for: blaOXA-1_1_J02967
# Total Gene Length: 831 bp
# Core Region (excluding edges): 795 bp
# Positions with at least 1 read: 795
# Coverage = (795 / 795) * 100 = 100.00%
# Total depth sum in core: 39368
# Average Depth = 39368 / 795 = 49.52x
# Number of Gaps: 0
#
# > Closest Homolog: blaOXA-320_1_KF151169
# > Similarity Score: 0.9766
#
# --- Analysis for: blaOXA-320_1_KF151169
# Total Gene Length: 831 bp
# Core Region (excluding edges): 795 bp
# Positions with at least 1 read: 789
# Coverage = (789 / 795) * 100 = 99.25%
# Total depth sum in core: 36784
# Average Depth = 36784 / 795 = 46.27x
# Number of Gaps: 6
#
#
# ....................................................................................................
#
# --- Analysis for: blaSHV-28_1_HM751101
# Total Gene Length: 861 bp
# Core Region (excluding edges): 825 bp
# Positions with at least 1 read: 825
# Coverage = (825 / 825) * 100 = 100.00%
# Total depth sum in core: 75842
# Average Depth = 75842 / 825 = 91.93x
# Number of Gaps: 0
#
# > Closest Homolog: blaSHV-100_1_AM941846
# > Similarity Score: 1.0000
#
# --- Analysis for: blaSHV-100_1_AM941846
# Total Gene Length: 900 bp
# Core Region (excluding edges): 864 bp
# Positions with at least 1 read: 864
# Coverage = (864 / 864) * 100 = 100.00%
# Total depth sum in core: 70691
# Average Depth = 70691 / 864 = 81.82x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: blaTEM-1B_1_JF910132
# Total Gene Length: 861 bp
# Core Region (excluding edges): 825 bp
# Positions with at least 1 read: 825
# Coverage = (825 / 825) * 100 = 100.00%
# Total depth sum in core: 41632
# Average Depth = 41632 / 825 = 50.46x
# Number of Gaps: 0
#
# > Closest Homolog: blaTEM-30_1_AJ437107
# > Similarity Score: 0.9775
#
# --- Analysis for: blaTEM-30_1_AJ437107
# Total Gene Length: 861 bp
# Core Region (excluding edges): 825 bp
# Positions with at least 1 read: 825
# Coverage = (825 / 825) * 100 = 100.00%
# Total depth sum in core: 36986
# Average Depth = 36986 / 825 = 44.83x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: fosA_3_ACWO01000079
# Total Gene Length: 420 bp
# Core Region (excluding edges): 384 bp
# Positions with at least 1 read: 384
# Coverage = (384 / 384) * 100 = 100.00%
# Total depth sum in core: 53800
# Average Depth = 53800 / 384 = 140.10x
# Number of Gaps: 0
#
# > Closest Homolog: fosA5_1_EU195449
# > Similarity Score: 0.7463
#
# --- Analysis for: fosA5_1_EU195449
# Total Gene Length: 420 bp
# Core Region (excluding edges): 384 bp
# Positions with at least 1 read: 384
# Coverage = (384 / 384) * 100 = 100.00%
# Total depth sum in core: 11791
# Average Depth = 11791 / 384 = 30.71x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: catB4_1_EU935739
# Total Gene Length: 549 bp
# Core Region (excluding edges): 513 bp
# Positions with at least 1 read: 513
# Coverage = (513 / 513) * 100 = 100.00%
# Total depth sum in core: 74192
# Average Depth = 74192 / 513 = 144.62x
# Number of Gaps: 0
#
# > Closest Homolog: catB3_1_AJ009818
# > Similarity Score: 0.7985
#
# --- Analysis for: catB3_1_AJ009818
# Total Gene Length: 633 bp
# Core Region (excluding edges): 597 bp
# Positions with at least 1 read: 417
# Coverage = (417 / 597) * 100 = 69.85%
# Total depth sum in core: 18023
# Average Depth = 18023 / 597 = 30.19x
# Number of Gaps: 180
#
#
# ....................................................................................................
#
# --- Analysis for: oqxA_1_EU370913
# Total Gene Length: 1176 bp
# Core Region (excluding edges): 1140 bp
# Positions with at least 1 read: 1140
# Coverage = (1140 / 1140) * 100 = 100.00%
# Total depth sum in core: 151089
# Average Depth = 151089 / 1140 = 132.53x
# Number of Gaps: 0
#
# > No similar genes found
#
#
# ....................................................................................................
#
# --- Analysis for: oqxB_1_EU370913
# Total Gene Length: 3153 bp
# Core Region (excluding edges): 3117 bp
# Positions with at least 1 read: 3117
# Coverage = (3117 / 3117) * 100 = 100.00%
# Total depth sum in core: 388102
# Average Depth = 388102 / 3117 = 124.51x
# Number of Gaps: 0
#
# > No similar genes found
#
#
# ....................................................................................................
#
# --- Analysis for: sul2_2_GQ421466
# Total Gene Length: 816 bp
# Core Region (excluding edges): 780 bp
# Positions with at least 1 read: 780
# Coverage = (780 / 780) * 100 = 100.00%
# Total depth sum in core: 35341
# Average Depth = 35341 / 780 = 45.31x
# Number of Gaps: 0
#
# > Closest Homolog: sul2_9_FJ197818
# > Similarity Score: 0.9987
#
# --- Analysis for: sul2_9_FJ197818
# Total Gene Length: 852 bp
# Core Region (excluding edges): 816 bp
# Positions with at least 1 read: 816
# Coverage = (816 / 816) * 100 = 100.00%
# Total depth sum in core: 34977
# Average Depth = 34977 / 816 = 42.86x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: tet(A)_4_AJ517790
# Total Gene Length: 1200 bp
# Core Region (excluding edges): 1164 bp
# Positions with at least 1 read: 1164
# Coverage = (1164 / 1164) * 100 = 100.00%
# Total depth sum in core: 82052
# Average Depth = 82052 / 1164 = 70.49x
# Number of Gaps: 0
#
# > Closest Homolog: tet(A)_6_AJ313332
# > Similarity Score: 0.9679
#
# --- Analysis for: tet(A)_6_AJ313332
# Total Gene Length: 1200 bp
# Core Region (excluding edges): 1164 bp
# Positions with at least 1 read: 1164
# Coverage = (1164 / 1164) * 100 = 100.00%
# Total depth sum in core: 68417
# Average Depth = 68417 / 1164 = 58.78x
# Number of Gaps: 0
#
#
# ....................................................................................................
#
# --- Analysis for: dfrA14_1_DQ388123
# Total Gene Length: 483 bp
# Core Region (excluding edges): 447 bp
# Positions with at least 1 read: 447
# Coverage = (447 / 447) * 100 = 100.00%
# Total depth sum in core: 23427
# Average Depth = 23427 / 447 = 52.41x
# Number of Gaps: 0
#
# > Closest Homolog: dfrA14_1_Z50805
# > Similarity Score: 0.9123
#
# --- Analysis for: dfrA14_1_Z50805
# Total Gene Length: 474 bp
# Core Region (excluding edges): 438 bp
# Positions with at least 1 read: 438
# Coverage = (438 / 438) * 100 = 100.00%
# Total depth sum in core: 16376
# Average Depth = 16376 / 438 = 37.39x
# Number of Gaps: 0
#
#
# ....................................................................................................
